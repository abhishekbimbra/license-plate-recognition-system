# %%
# !nvidia-smi

# %%
# !git clone https://github.com/THU-MIG/yolov10.git
# %cd yolov10

# %% [markdown]
# # Installing Requriments

# %%
# !pip install -q .

# %%
import os
import urllib.request
#Create a directory for the weights in the current working directory
weights_dir = os.path.join(os.getcwd(), 'weights')
os.makedirs(weights_dir, exist_ok = True)
#urls of the weights file
urls = ["https://github.com/THU-MIG/yolov10/releases/download/v1.1/yolov10n.pt",
        "https://github.com/THU-MIG/yolov10/releases/download/v1.1/yolov10s.pt",
        "https://github.com/THU-MIG/yolov10/releases/download/v1.1/yolov10m.pt",
        "https://github.com/THU-MIG/yolov10/releases/download/v1.1/yolov10b.pt",
        "https://github.com/THU-MIG/yolov10/releases/download/v1.1/yolov10l.pt",
        "https://github.com/THU-MIG/yolov10/releases/download/v1.1/yolov10x.pt"]

#Download each file
for url in urls:
  filename = os.path.basename(url)
  filepath = os.path.join(weights_dir, filename)
  urllib.request.urlretrieve(url, filepath)
  print(f"Downloaded: {filepath}")

# %%
import os

# List all files in the weights directory
print("\nContents of 'weights' directory:")
print(os.listdir(weights_dir))

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="tFpTLSEyoQWZmHOag933")
project = rf.workspace("roboflow-universe-projects").project("license-plate-recognition-rxg4e")
version = project.version(11)
dataset = version.download("yolov8")

# %%
# %cd '/kaggle/working/yolov10'

# %% [markdown]
# # Train Custom Model

# %%
# !pip3 install -U ultralytics

# %%
import shutil

uploaded_yaml_path = '/kaggle/input/data-yaml/data.yaml'
destination_path = '/kaggle/working/yolov10/License-Plate-Recognition-11/data.yaml'

# Copy and overwrite
shutil.copy(uploaded_yaml_path, destination_path)

print("data.yaml replaced successfully!")

# %%
# !yolo task=detect mode=train epochs=50 batch=16 plots=True model='weights/yolov10n.pt' data='/kaggle/working/yolov10/License-Plate-Recognition-11/data.yaml'

# %%
from IPython.display import Image

Image("/kaggle/working/yolov10/runs/detect/train/labels.jpg")

# %%
Image("/kaggle/working/yolov10/runs/detect/train/PR_curve.png")

# %%
Image("/kaggle/working/yolov10/runs/detect/train/R_curve.png")

# %%
Image("/kaggle/working/yolov10/runs/detect/train/P_curve.png")

# %%
Image("/kaggle/working/yolov10/runs/detect/train/F1_curve.png")

# %%
Image("/kaggle/working/yolov10/runs/detect/train/confusion_matrix.png")

# %%
Image("/kaggle/working/yolov10/runs/detect/train/confusion_matrix_normalized.png")

# %%
Image("/kaggle/working/yolov10/runs/detect/train/results.png")

# %%
Image("/kaggle/working/yolov10/runs/detect/train/train_batch0.jpg")

# %%
Image("/kaggle/working/yolov10/runs/detect/train/val_batch0_pred.jpg")

# %%
Image("/kaggle/working/yolov10/runs/detect/train/val_batch1_pred.jpg")

# %% [markdown]
# # Inference on Image

# %%
# !yolo task=detect mode=predict conf=0.25 save=True model='/kaggle/working/yolov10/runs/detect/train/weights/best.pt' source='/kaggle/input/inference/number plate .png'

# %%
from IPython.display import Image
Image(filename='/kaggle/working/yolov10/runs/detect/predict/number plate .jpg')

# %%
# !yolo task=detect mode=predict conf=0.25 save=True model='/kaggle/working/yolov10/runs/detect/train/weights/best.pt' source='/kaggle/input/inference2/number plate 2.png'

# %%
from IPython.display import Image
Image(filename='/kaggle/working/yolov10/runs/detect/predict2/number plate 2.jpg')

# %% [markdown]
# # Inference on Image

# %%
# !yolo task=detect mode=predict conf=0.25 save=True model='/kaggle/working/yolov10/runs/detect/train5/weights/best.pt' source='/kaggle/input/video-inference/2103099-uhd_3840_2160_30fps.mp4'

# %%
# !ffmpeg -i /kaggle/working/yolov10/runs/detect/predict3/2103099-uhd_3840_2160_30fps.avi \
  -vcodec libx264 -crf 24 /kaggle/working/yolov10/runs/detect/predict3/output.mp4 -y

# %%
from IPython.display import Video

Video("/kaggle/working/yolov10/runs/detect/predict3/output.mp4", width=700, embed=True)
